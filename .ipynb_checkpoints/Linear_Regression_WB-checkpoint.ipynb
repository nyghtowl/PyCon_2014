# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
from linear_regression_ex import *

# %%
main()
# Out:
# Coefficients: 918.38
# Residual sum of squares: 3540.17
# Variance score: 0.41
