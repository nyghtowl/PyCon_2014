# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %% [raw]
# Feb - First Draft with scikit learn example

# %%
from linear_regression_ex import *

# %%
# %timeit()

main();
# Out:
# 10000000 loops, best of 3: 23.6 ns per loop
# X
#  (442, 1, 10)
# X every 2 (442, 1, 10)
# Coefficients: 916.85
# Residual sum of squares: 60.04
# Variance score: 0.38

# %%
data = datasets.load_diabetes()

# %%
data_lfw = datasets.load_iris

# %%
data_lfw.func_doc
# Out:
# "Load and return the iris dataset (classification).\n\n    The iris dataset is a classic and very easy multi-class classification\n    dataset.\n\n    =================   ==============\n    Classes                          3\n    Samples per class               50\n    Samples total                  150\n    Dimensionality                   4\n    Features            real, positive\n    =================   ==============\n\n    Returns\n    -------\n    data : Bunch\n        Dictionary-like object, the interesting attributes are:\n        'data', the data to learn, 'target', the classification labels,\n        'target_names', the meaning of the labels, 'feature_names', the\n        meaning of the features, and 'DESCR', the\n        full description of the dataset.\n\n    Examples\n    --------\n    Let's say you are interested in the samples 10, 25, and 50, and want to\n    know their class name.\n\n    >>> from sklearn.datasets import load_iris\n    >>> data = load_iris()\n    >>> 
# ...

# %%
data.keys()
# Out:
# ['data', 'target']

# %%
data.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990842, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06832974, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286377, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04687948,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452837, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00421986,  0.00306441]])

# %%
data.target
# Out:
# array([ 151.,   75.,  141.,  206.,  135.,   97.,  138.,   63.,  110.,
#         310.,  101.,   69.,  179.,  185.,  118.,  171.,  166.,  144.,
#          97.,  168.,   68.,   49.,   68.,  245.,  184.,  202.,  137.,
#          85.,  131.,  283.,  129.,   59.,  341.,   87.,   65.,  102.,
#         265.,  276.,  252.,   90.,  100.,   55.,   61.,   92.,  259.,
#          53.,  190.,  142.,   75.,  142.,  155.,  225.,   59.,  104.,
#         182.,  128.,   52.,   37.,  170.,  170.,   61.,  144.,   52.,
#         128.,   71.,  163.,  150.,   97.,  160.,  178.,   48.,  270.,
#         202.,  111.,   85.,   42.,  170.,  200.,  252.,  113.,  143.,
#          51.,   52.,  210.,   65.,  141.,   55.,  134.,   42.,  111.,
#          98.,  164.,   48.,   96.,   90.,  162.,  150.,  279.,   92.,
#          83.,  128.,  102.,  302.,  198.,   95.,   53.,  134.,  144.,
#         232.,   81.,  104.,   59.,  246.,  297.,  258.,  229.,  275.,
# ...

# %% [raw]
# 3-10 Switching to head size and brain weight data

# %%
from lr_brain_body import *

# %%
main() # female
# Out:
# Residual sum of squares: 49.18
# Variance score: 0.62

# %%
main()
# Out:
# Residual sum of squares: 78.48
# Variance score: 0.15

# %%
main()
# Out:
# Residual sum of squares: 94.58
# Variance score: 0.02

# %%
main() # both
# Out:
# Residual sum of squares: 67.68
# Variance score: 0.56

# %%
main()
# Out:
# Residual sum of squares: 74.83
# Variance score: 0.63

# %%
main()
# Out:
# Residual sum of squares: 0.15
# Variance score: 0.68

# %%
main()
# Out:
# Residual sum of squares: 0.14
# Variance score: 0.77

# %%
main()
# Out:
# Root Mean Squared Error: 0.16
# Accuracy: 0.59

# %%
main()
# Out:
# Root Mean Squared Error: 0.17
# Accuracy: 0.56

# %%
main()
# Out:
# Root Mean Squared Error: 0.14
# Accuracy: 0.72

# %%
data = pd.read_csv('./data/both_brain_body.txt', sep=r"\s*", converters={'Head_Size': cm_inch, 'Brain_Weight': grm_pd}, header=0)

# %%
type(data.iloc[1,1])
# Out:
# numpy.int64

# %% [raw]
# Creating scatter plot without line for preseantation

# %%
import lr_brain_body as lb

# %%
def visualize2(X_test, y_test):
    plt.scatter(X_test, y_test,  color='black')
    plt.title('Linear Regression - Predict Brain Weight by Head Size', fontsize=14)
    plt.xlabel('Head Size (in^3)')
    plt.ylabel('Brain Weight (lb)')
    plt.xlim(180,280)
    plt.ylim(2.4,3.8)

    plt.savefig('body_brain_scatter_ex.png')


    plt.show()

# %%
data = lb.load_data('./data/both_brain_body.txt')

# %%
X, y = np.array(data['Head_Size']), np.array(data['Brain_Weight'])

# %%
visualize2(X, y)

# %% [raw]
# 4/6 - Updated code and illustrations. Needed to break down further and create more graphs.

# %%
from lr_brain_body import *

# %%
model = main()
# Out:
# Accuracy: 0.74
# Root Mean Squared Error: 0.12

# %%
model.coef_ # m - slope
# Out:
# array([ 0.00886553])

# %%
model.intercept_ # b
# Out:
# 0.89017452445353573

# %%
X.shape
# Out:
# (110,)

# %%
temp = X[:,np.newaxis]

# %%
temp.shape
# Out:
# (110, 1)

# %% [markdown]
# 4/8 - Providng color adjustment to graphs

# %%
from lr_brain_body import *

# %%
data = load_data('./data/both_brain_body.txt')

# %%
X, y = np.array(data['Head_Size']), np.array(data['Brain_Weight'])

# %%
X_train, X_test, y_train, y_test = create_datasets(X[:,np.newaxis], y, 1)

# %%
model = build_model(X_train, y_train)

# %%
predict_eval(model, X_test, y_test)
# Out:
# Accuracy: 0.63
# Root Mean Squared Error: 0.14

# %%
scatter_split_plot(model, [X_train, X_test, y_train, y_test], 'Train & Test Data Split', 'split_scatter_ex.png')

# %%
result = model.predict(240)

# %%
model = main()
# Out:
# Accuracy: 0.63
# Root Mean Squared Error: 0.14

# %% [raw]
# Working on the font size

# %%
main()
# Out:
# Accuracy: 0.63
# Root Mean Squared Error: 0.14
# LinearRegression(copy_X=True, fit_intercept=True, normalize=False)

# %%
|
