# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
from linear_regression_ex import *

# %%
# %timeit()

main();
# Out:
# 10000000 loops, best of 3: 24.5 ns per loop
# Coefficients: 993.17
# Residual sum of squares: 3464.06
# Variance score: 0.33

# %%
data = datasets.load_diabetes()

# %%
data_lfw = datasets.load_iris

# %%
data_lfw.func_doc
# Out:
# "Load and return the iris dataset (classification).\n\n    The iris dataset is a classic and very easy multi-class classification\n    dataset.\n\n    =================   ==============\n    Classes                          3\n    Samples per class               50\n    Samples total                  150\n    Dimensionality                   4\n    Features            real, positive\n    =================   ==============\n\n    Returns\n    -------\n    data : Bunch\n        Dictionary-like object, the interesting attributes are:\n        'data', the data to learn, 'target', the classification labels,\n        'target_names', the meaning of the labels, 'feature_names', the\n        meaning of the features, and 'DESCR', the\n        full description of the dataset.\n\n    Examples\n    --------\n    Let's say you are interested in the samples 10, 25, and 50, and want to\n    know their class name.\n\n    >>> from sklearn.datasets import load_iris\n    >>> data = load_iris()\n    >>> 
# ...

# %%
data.keys()
# Out:
# ['data', 'target']

# %%
data.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990842, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06832974, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286377, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04687948,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452837, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00421986,  0.00306441]])

# %%
data.target
# Out:
# array([ 151.,   75.,  141.,  206.,  135.,   97.,  138.,   63.,  110.,
#         310.,  101.,   69.,  179.,  185.,  118.,  171.,  166.,  144.,
#          97.,  168.,   68.,   49.,   68.,  245.,  184.,  202.,  137.,
#          85.,  131.,  283.,  129.,   59.,  341.,   87.,   65.,  102.,
#         265.,  276.,  252.,   90.,  100.,   55.,   61.,   92.,  259.,
#          53.,  190.,  142.,   75.,  142.,  155.,  225.,   59.,  104.,
#         182.,  128.,   52.,   37.,  170.,  170.,   61.,  144.,   52.,
#         128.,   71.,  163.,  150.,   97.,  160.,  178.,   48.,  270.,
#         202.,  111.,   85.,   42.,  170.,  200.,  252.,  113.,  143.,
#          51.,   52.,  210.,   65.,  141.,   55.,  134.,   42.,  111.,
#          98.,  164.,   48.,   96.,   90.,  162.,  150.,  279.,   92.,
#          83.,  128.,  102.,  302.,  198.,   95.,   53.,  134.,  144.,
#         232.,   81.,  104.,   59.,  246.,  297.,  258.,  229.,  275.,
# ...

# %%
from lr_brain_body import *

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-83-58ca95c5b364> in <module>()
# ----> 1 main()
#
# /Users/willow/Dropbox/Wiley_Warrick/Conferences/PyCon/linear_regression_example/lr_brain_body.py in main()
#      39     data = load_data('./data/brain_body_weight.txt')
#      40     X_train, X_test, y_train, y_test = create_datasets(data)
# ---> 41     model = build_model(X_train, y_train)
#      42     predict_eval(model, X_test, y_test)
#      43     visualize(model, X_test, y_test)
#
# /Users/willow/Dropbox/Wiley_Warrick/Conferences/PyCon/linear_regression_example/lr_brain_body.py in build_model(X_train, y_train)
#      17 def build_model(X_train, y_train):
#      18     ml = linear_model.LinearRegression()# Create regression object
# ---> 19     return ml.fit(X_train, y_train) # Train the model
#      20
#      21 def predict_eval(model, X_test, y_test):
#
# ...

# %%
body_data = pd.read_csv('./data/brain_body_weight.txt', sep=r"\s*", header=0, index_col=0)

# %%
body_data.tail()
# Out:
# /Users/willow/anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# /Users/willow/anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
#        BrainWeight  BodyWeight
# Index
# 58         160.000       169.0
# 59           0.900         2.6
# 60           1.620        11.4
# 61           0.104         2.5
# 62           4.235        50.4
